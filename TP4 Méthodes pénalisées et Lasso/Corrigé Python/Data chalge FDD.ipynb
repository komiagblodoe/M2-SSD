# %%
import pandas as pd

#importation des jeu de données
train = pd.read_csv("C:/Users/im2ag/Desktop/DATA-CHALLENGE/spectra-train.csv", sep='; ')
test = pd.read_csv("C:/Users/im2ag/Desktop/DATA-CHALLENGE/spectra-test.csv", sep=', ')
meta_train = pd.read_csv("C:/Users/im2ag/Desktop/DATA-CHALLENGE/meta-train.csv", sep=', ')
meta_test = pd.read_csv("C:/Users/im2ag/Desktop/DATA-CHALLENGE/meta-test.csv", sep=', ')

print(train)
# Out:
# C:\Users\im2ag\Downloads\WPy64-3741\python-3.7.4.amd64\lib\site-packages\ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# C:\Users\im2ag\Downloads\WPy64-3741\python-3.7.4.amd64\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# ...
